# %%
import pandas as pd
import numpy as np

# %%
yelp = pd.read_csv("yelp.csv")

# %%
yelp.head()
# Out:
#                                              address  \
# 0                                                NaN
# 1  \r\n        51 N Margin St,Boston, MA 02113\r\...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         area  \
# 0    Serving Boston and the Surrounding Area
# 1                             51 N Margin St
# 2  Serving Brighton and the Surrounding Area
# 3    Serving Boston and the Surrounding Area
# 4    Serving Boston and the Surrounding Area
#
#                                           categories  \
# 0    Dog Walkers,Pet Sitting,Dog Walkers,Pet Sitting
# 1  Pet Training,Pet Groomers,Dog Walkers,Pet Trai...
# 2  Dog Walkers,Pet Boarding,Dog Walkers,Pet Boarding
# 3    Dog Walkers,Pet Sitting,Dog Walkers,Pet Sitting
# 4  Dog Walkers,Pet Sitting,Dog Walkers,Pet Sittin...
#
#                          lastrev  \
# ...

# %%
yelp = yelp.replace(to_replace ='[\r\n]', value = '', regex = True)

# %%
yelp.head()
# Out:
#                                        address  \
# 0                                          NaN
# 1          51 N Margin St,Boston, MA 02113
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                         area  \
# 0    Serving Boston and the Surrounding Area
# 1                             51 N Margin St
# 2  Serving Brighton and the Surrounding Area
# 3    Serving Boston and the Surrounding Area
# 4    Serving Boston and the Surrounding Area
#
#                                           categories                lastrev  \
# 0    Dog Walkers,Pet Sitting,Dog Walkers,Pet Sitting          2/27/2009
# 1  Pet Training,Pet Groomers,Dog Walkers,Pet Trai...          9/10/2019
# 2  Dog Walkers,Pet Boarding,Dog Walkers,Pet Boarding          5/12/2019
# 3    Dog Walkers,Pet Sitting,Dog Walkers,Pet Sitting          8/29/2016
# ...

# %%
yelp.to_csv('yelp.csv')
